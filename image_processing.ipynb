# %%
import dlib
from PIL import Image
import face_recognition
from numpy import array

# %%
img2 = Image.open('/home/ines/Downloads/ines.jpg')
imgmakram= cv2.imread('/home/ines/Downloads/pic.jpg')
img= cv2.imread('/home/ines/Downloads/ines.jpg')

# %%
#convert the image to a matrix

# %%
#arr = array(img)
arr=array(imgmakram)

# %%
arr
# Out:
# array([[[161, 143, 132],
#         [164, 146, 135],
#         [164, 146, 135],
#         ...,
#         [ 70,  60,  53],
#         [ 70,  60,  53],
#         [ 70,  60,  53]],
#
#        [[162, 144, 133],
#         [164, 146, 135],
#         [164, 146, 135],
#         ...,
#         [ 71,  61,  54],
#         [ 70,  60,  53],
#         [ 70,  60,  53]],
#
#        [[162, 146, 133],
#         [164, 148, 135],
#         [163, 147, 135],
#         ...,
#         [ 71,  63,  56],
#         [ 70,  62,  55],
#         [ 70,  62,  55]],
#
#        ...,
#
#        [[ 30,  37,  57],
#         [ 28,  37,  57],
#         [ 30,  36,  59],
#         ...,
#         [ 54,  65,  92],
#         [ 54,  67,  93],
#         [ 54,  67,  93]],
#
#        [[ 23,  34,  48],
#         [ 23,  36,  50],
#         [ 26,  36,  53],
#         ...,
#         [ 50,  65,  91],
#         [ 50,  65,  91],
#         [ 49,  64,  90]],
#
#        [[ 19,  34,  43],
#         [ 22,  37,  46],
#         [ 24,  37,  51],
# ...

# %%
#only to test convert this late matrix to the image and see if the conversion went well

# %%
img = Image.fromarray(arr,'RGB')
img.save('my.jpg')
img.show()

# %%
#make the picture clearer by

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img2,-1,kernel)

plt.subplot(121),plt.imshow(img2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
#brightenning up the image using cv2

# %%
def increase_brightness(img, value=30):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

# %%
l=increase_brightness(img2,30)

# %%
k = Image.fromarray(l)
k.save('my.jpg')
k.show()

# %%
#saving the modified image

# %%
from PIL import Image  
import PIL

# %%
imagesaved = k.save("/home/ines/dockerprojects/face_recognition/examples/imagesave.jpg")

# %%
#Loading the image and running the face recongnition modele - using dlib library

# %%
INES_image = face_recognition.load_image_file("/home/ines/dockerprojects/face_recognition/examples/INES.jpg")

# %%
imagesaved_face_encoding = face_recognition.face_encodings(imagesaved_image)[0]

# %%
unknown_image = face_recognition.load_image_file("/home/ines/dockerprojects/face_recognition/examples/imagesave.jpg")

# %%
unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]

# %%
known_faces = [
    Ines_face_encoding
]

# %%
results = face_recognition.compare_faces(known_faces, unknown_face_encoding)

# %%
print("Is the unknown face a picture of Ines? {}".format(results[0]))
# Out:
# Is the unknown face a picture of Ines? True

# %%
print("Is the unknown face a new person that we've never seen before? {}".format(not True in results))
# Out:
# Is the unknown face a new person that we've never seen before? False
